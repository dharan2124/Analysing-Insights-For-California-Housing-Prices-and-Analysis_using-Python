# %% [markdown]
# ### INTRODUCTION:
#
# This dataset gives us a brief description about the california housing data.
# By analysing this california house dataset we will determine the approximate price for the houses.
# The main aim of this dataset is to predict the median house prices for california.
# This dataset consists of the following features are as follows:

# %% [markdown]
#  ### FEATURES:
#
# 1.longitude:A measure of distance a house is located horizontally that is from west to east,a higher value is further towards west.Statistically it comes under numerical data type, i.e.,Continuous data.
#
# 2.latitude:A measure of distance a house is located vertically that is towards north,a higher value is further towards north.Statistically it comes under numerical data type, i.e.,Continuous data
#
# 3.housing_median_age:It is Median age of a house.Statistically it is of quantitative datatype,i.e.,Continuous data.
#
# 4.total_rooms:Total number of rooms within a block.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 5.total_bedrooms:Total number of bedrooms within a block.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 6.population:Total number of people residing within a block.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 7.households:Total number of households,a group of people residing within a homeunit.Statistically it is of quantitative data type,i.e.,discrete data.
#
# 8.median_income:Median income of households within a block of houses.(measured in tens of thousands of US Dollars).It comes under continuous data.
#
# 9.median_house_value:Median house value for households within a block(measured in US Dollars).It comes under continuous data.
#
# 10.Ocean_proximity:Location of the house with respect to ocean.Statistically it is of categorical data i.e.,it is of nominal data type.

# %%
# the file reading

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
conda install openpyxl
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0

# %%
df= pd.read_excel("D:\dse\python inter mandatory project\housing.xlsx")
#print output
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df.shape #shape func() gives us the total number of rows and columns present in a dataset.
# Out:
# (20640, 10)

# %%
df.dtypes #The dtype() function is used to create a data type object.
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# median_house_value      int64
# ocean_proximity        object
# dtype: object

# %%
df.info()   # we can see how many data instances are there and how many rows and colomns are present.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
df.describe()  # The describe() function computes a summary of statistics pertaining to the DataFrame columns
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
## check nulls of data 
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# From the above it is to be noted that python reads longitude,latitude,housing_median_age,total_rooms,total_bedrooms,population,households,median_income,median_house_value as float.
# while python reads ocean_proximity as object.
#
# It seems that Dataset is a contains 20640 instances and only 207 null values in total bedrooms feature, and also all datatypes is float64 as they are continuous numerical features except the (ocean_proximity) column which is nominal categorical Feature

# %%
# to visualize the outliers of the given housing dataset
# Select relevant numerical columns
numerical_columns = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population'
                     ,'households', 'median_income', 'median_house_value']

# Create box plots to visualize outliers
plt.figure(figsize=(16, 8))
sns.boxplot(data=df[numerical_columns])
plt.xticks(rotation=45)
plt.title('Boxplot for Numerical Features')
plt.show()

# %%
The box plot visualization for both longitude,latitude,housing_median_age reveals a relatively constant 
and uniform distribution across the dataset. The absence of vertical spread in the boxes indicates that the 
values are concentrated within a narrow range.
There are few outliers in remaining categories.

# %%
# Count the occurrences of each category
category_counts = df['ocean_proximity'].value_counts()

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')
plt.title('Distribution of Ocean Proximity')
plt.xlabel('Ocean Proximity')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 1. What is the average median income of the data set and check the distribution of data using appropriate plots? Please explain the distribution of the plot.

# %%
average_median_income = df['median_income'].mean()     #mean()function gives the mean of the values for the requested axis
print(f"The average median income in the dataset is: {average_median_income}")     #mean gives the average values of a dataset
# Out:
# The average median income in the dataset is: 3.8706710029069766

# %% [markdown]
# From the above code it is to be noted that the average median_income of this dataset is 3.8706 that is 3.9

# %%
#creating a histogram for the column median income
plt.hist(df['median_income'],bins = 15,edgecolor = 'black',color = 'skyblue')

#creating values for fontdict for title and labels
f1 = {'color':'red','size':15}
f2 = {'color':'green','size':12}

#creating title and labels
plt.xlabel('Median Income',fontdict=f2)
plt.ylabel('Frequency',fontdict=f2)
plt.title('Distribution of Median Income',fontdict=f1)

plt.show()

# %% [markdown]
# From the above plot,we can observe that whose median income is in the range of 3(tens of thousands of US dollars) has the highest frequency i.e districts with income 3(tens of thousands of US dollars) are around 5500 and the 2nd highest is median income is in the range of 4(tens of thousands of US dollars).They are around 4500.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['median_income'], kde=True, color='skyblue')
plt.title('Distribution of Median Income')
plt.xlabel('Median Income')
plt.ylabel('Frequency')
plt.show()


# This code creates a histogram to visualize the distribution of "median_income"
# The x-axis shows "Median Income,"
# the y-axis shows frequency
# Setting 'kde=True' enables Kernel Density Estimation for data visualization or smoothing.

# %% [markdown]
# #### 2. Draw an appropriate plot of housing_median_age and explain your observations.

# %%
plt.hist(df["housing_median_age"],bins=20, color='skyblue', edgecolor='black') #Histogram is used to see the distribution of a numerical value.


#creating values for fontdict for title and labels
f1 = {'color':'green','size':15}
f2 = {'color':'brown','size':12}

#creating title and labels
plt.xlabel('Median Age of a house',fontdict=f2)
plt.ylabel('Frequency',fontdict=f2)
plt.title('Distribution of Median age of a house',fontdict=f1)

plt.show()

# %% [markdown]
# #### 3. Show with the help of visualization, how median_income and median_house_values are related?

# %%
sns.scatterplot(x="median_house_value",y="median_income",alpha=0.4,
                marker = 'h', edgecolor = 'm', facecolor = 'c',data=df) 
sns.set_style('darkgrid')
##scatter plot gives a relation between two numerical values.
#x-axis median_house_value  #Y axis median_income

# %% [markdown]
# From the above visualisation it is to be analysed that with an increase in the median_house_value there is also an increase in the median income.While,an outlier is present in median_house_value which is shown in the fig.Therefore,median_house_value is directly proportional to median income.

# %% [markdown]
# #### 4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

# %%
df[df.isnull().any(axis=1)]    #The isnull() method returns a DataFrame object where all the values are 
                               #replaced with a Boolean value True for NULL values, and otherwise False.
                               #Here missing values are denoted by NaN
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                  47         1256             NaN
# 341      -122.17     37.75                  38          992             NaN
# 538      -122.28     37.78                  29         5154             NaN
# 563      -122.24     37.75                  45          891             NaN
# 696      -122.10     37.69                  41          746             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                  18         3620             NaN
# 20268    -119.18     34.19                  19         2393             NaN
# 20372    -118.88     34.17                  15         4260             NaN
# 20460    -118.75     34.29                  17         5512             NaN
# 20484    -118.72     34.28                  17         3051             NaN
#
# ...

# %% [markdown]
# In the above code,missing values are identified by using isnull()method.This missing values are identified in the column 'total_bedrooms'.

# %%
new_data=df.dropna(subset=["total_bedrooms"])#dropna() method allows the user to analyze and drop Rows/Columns with Null values in different ways.
new_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# While in the above code the missing values are dropped from the column named'total_bedrooms'by using dropna() method.

# %% [markdown]
# #### 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# %%
df["total_bedrooms"]=df["total_bedrooms"].fillna(df['total_bedrooms'].mean())
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# In the above code,a new dataset had been created where the missing values in the 'total_bedrooms'which are denoted by NaN are replaced with the mean value of the 'total_bedrooms'.
#
# For eg:row no.290,341,538 and other rows with the missing values are replaced with the mean value of 'total_bedrooms' i.e.,537.8705525375618,respectively.

# %%
from scipy.stats import skew

# Assuming numerical_features is a list of column names with numerical data
numerical_features = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']

# Calculate skewness for each numerical feature
skewness_values = df[numerical_features].apply(lambda x: skew(x))

# Display skewness values
print("Skewness values:")
print(skewness_values)
# Out:
# Skewness values:
# longitude            -0.297780
# latitude              0.465919
# housing_median_age    0.060326
# total_rooms           4.147042
# total_bedrooms        3.476771
# population            4.935500
# households            3.410190
# median_income         1.646537
# median_house_value    0.977692
# dtype: float64

# %%
The interpretation of skewness values:

A skewness value around 0 indicates a roughly symmetric distribution.
Positive skewness (> 0) indicates a right-skewed (positively skewed) distribution.
Negative skewness (< 0) indicates a left-skewed (negatively skewed) distribution.

# %% [markdown]
# #### 6. Write a programming construct  (create a user defined function) to calculate the median value of the data set wherever required.

# %%
df.head()             #The head() returns the first 5 rows for the object based on position.
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %% [markdown]
# MEDIAN():
#
# Basically it is defined as the 50th percentile of the set of measurements,when observed measurements are ranked from smallest to highest. It is not Sensitive to Outliers. Commonly used by Discrete and Continuous data.
#
# A median for a datarframe can be known by using: df['column_name'].median()
#
# A point to be noted that median() can be calculated for Discrete and Continuous data.

# %%
#creating a function for calculating mean of a particular column
def median_calculation(df, column_name):

  #selecting a specified column and calculating median
  median_value = df[column_name].median()

  return median_value

#taking column name input from user
column_name = input('Enter the column name on which you want to calculate median value: ')

#calling the user defined function to calculate the median of particular column
median_income = median_calculation(df,column_name)
print('Median value: ',median_income)
# Out:
# Enter the column name on which you want to calculate median value: median_house_value
# Median value:  179700.0

# %% [markdown]
# #### 7. Plot latitude versus longitude and explain your observations.

# %%
sns.scatterplot(x='latitude',y='longitude',data=df,marker = 'H', edgecolor='r', facecolor = 'cyan')  
sns.set_style('darkgrid')
#creating values for fontdict for title and labels
f1 = {'color':'Red','size':15}
f2 = {'color':'blue','size':12}

#creating title and labels
plt.xlabel('Latitude',fontdict = f2)
plt.ylabel('Longitude',fontdict = f2)
plt.title('Latitude vs Longitude',fontdict = f1)
#Scatter plot gives a relationship between two numerical values.                                                    
#x-axis = latitude #y-axis = longitude
# Out:
# Text(0.5, 1.0, 'Latitude vs Longitude')

# %% [markdown]
# From the above plot,it is to be noted that with an decrease in longitude,latitude is increased..From this we can say that longitude is inversely proportional to latitude.
#
# From the above plot it is to be noted that latitude vs longitude has negative correlation as here y-axis is increasing while x-axis is decreasing,i.e., both are moving in an opposite direction.

# %% [markdown]
# #### 8. Create a data set for which the ocean_proximity is Near ocean.

# %%
#checking for the unique values in column 'occean_proximity'
df.ocean_proximity.unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
new_data=df[df["ocean_proximity"]=="NEAR OCEAN"] 
new_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %% [markdown]
# #### 9. Find the mean and median of the median income for the data set created in question 8.

# %%
mean=new_data['median_income'].mean()   
print('The mean of the median income where ocean proximity is near ocean is: ',mean)

#mean() gives the averages of the data
#mean()is applicable for discrete and continuous data but not for categorical data.
# Out:
# The mean of the median income where ocean proximity is near ocean is:  4.0057848006019565

# %%
median=new_data['median_income'].median() 
print('The median of the median income where ocean proximity is near ocean is: ',median)
#median()value gives the 50th percentile of the set of all observations.
# Out:
# The median of the median income where ocean proximity is near ocean is:  3.64705

# %% [markdown]
# The mean and median value of the 'median_income'in the created new dataset are:4.005784 and 3.64705 respectively.

# %% [markdown]
# #### 10. Please create a new column named total_bedroom_size. If size 10 or less. It should be quoted as small. If the size is 11 or more but 1000 less, it should be medium, otherwise it should be large.

# %%
def newcolumn(total_bedrooms):
  if total_bedrooms <= 10:
    return 'Small'
  elif 11<= total_bedrooms <=1000:
    return 'Medium'
  else:
    return 'large'
df['total_bedroom_size'] = df['total_bedrooms'].apply(newcolumn)
df

#  This code defines a function categorize_bedroom_size that takes the value of 'total_bedrooms' and returns the 
# corresponding category. The apply method is then used to apply this function to each row of the 'total_bedrooms' column, 
# creating the new column 'total_bedroom_size' in the DataFrame df
# in DataFrame df using this function. The updated DataFrame are displayed for analysis.
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# In the above data set a new column named total_bedroom_size had been added.Where the total_bedroom_size had been compared to the total_bedrooms while mentioning about the sizes of the total_bedroom_size,where:
#
# If the total_bedroom_size <=10 it is indicated as "small" If the total_bedroom_size >=11 or <=1000 it is indicated as "medium" If the total_bedroom_size >1000 it is indicated as "large"

# %% [markdown]
# ### CONCLUSION:
# 1.From the given dataset it is to be noted that the outliers are present for median_house_value.
#
# 2.All the features present in this dataset are of float type except ocean_proximity which is of object datatype.
#
# 3.plot between latitude and longitude is inversely proportional to each other as within increase in latitude,there is decrease in longitude.Therefore ,it has a negative correlation
#
# 4.median_house_value is directly proportional to median income.
